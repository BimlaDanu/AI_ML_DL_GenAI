# %%
# pip install openai

# %%
## pip install openai
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ["OPENROUTER_API_KEY"],
)

response = client.chat.completions.create(
    model="meta-llama/llama-3.1-8b-instruct",
    messages=[{"role": "user", "content": "What is a large language model?"}],
)
print(response.choices[0].message.content)
# Out:
# A large language model (LLM) is a type of artificial intelligence (AI) that is trained on vast amounts of text data to generate human-like language. LLMs have been designed to process and generate human language, including text, speech, and even images with text overlays.
#
# Large language models are typically characterized by their massive scale, which refers to:
#
# 1. **Training data size**: LLMs are trained on enormous text datasets, often in the order of tens of gigabytes or even terabytes. This massive corpus of text allows the model to learn about the complexities of language, including syntax, semantics, and context.
# 2. **Model complexity**: LLMs have a large number of parameters (weights) that are adjusted during training to optimize the model's performance. These parameters can number in the billions, making it a massive computational task to train the model.
# 3. **Computational resources**: LLMs often require substantial computational resources, including powerful GPUs (Graphics Processing Units), TPUs (Tensor Processing Units), or even specialized hardware (e.g., Google's Tensor Processing Hardware). This enables the model to process and analyze vast amounts of data simultaneously.
#
# The characteristics of large language models include:
#
# * **Multi-layer perceptron architecture**: LLMs typically consist of multiple layers of artificial neural networks, where each layer processes and transforms the input data.
# * **Transformers**: A popular transformer architecture, known as the Transformer-XL, is commonly used in LLMs to model and capture long-range dependencies in text data.
# * **Masked language modeling**: LLMs often use masked language modeling as a training objective, where a portion of the input text is randomly removed (masked) and the model predicts the missing word or phrase.
# * **Pretrained weights**: LLMs are typically pre-trained on large text datasets and fine-tuned on smaller, task-specific datasets to adapt the model to a particular use case or problem.
#
# Large language models have numerous applications, including:
#
# 1. **Chatbots and dialogue systems**: LLMs can be used to power conversational AI systems that engage in natural-sounding conversations with humans.
# 2. **Language translation**: LLMs can be used to develop language translation systems that can translate text from one language to another.
# 3. **Text summarization**: LLMs can be used to automatically summarize long pieces of text into concise summaries.
# 4. **Creative writing**: LLMs can be used to generate creative writing, such as poetry, stories, and even entire novels.
#
# Some notable examples of large language models include:
#
# 1. **BERT (Bidirectional Encoder Representations from Transformers)**: A popular LLM developed by Google that uses a transformer architecture.
# 2. **RoBERTa (Robustly Optimized BERT Pretraining)**: An LLM developed by Facebook AI Research (FAIR) that improves upon BERT's performance.
# 3. **Megatron-LM**: An LLM developed by Facebook AI Research (FAIR) that achieves state-of-the-art performance on various natural language processing tasks.
#
# The development of large language models has opened up new possibilities for natural language processing and text analysis, with potential applications in areas like language translation, text summarization, and conversational AI. However, the training and deployment of these models also raise important questions about data bias, explainability, and the potential risks of large-scale language models.

# %%
import os
from openai import OpenAI

client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.environ["OPENROUTER_API_KEY"],

)

response = client.chat.completions.create(
    model="openai/gpt-5-mini",
    #model="meta-llama/llama-3.1-8b-instruct",
    #model="claude-sonnet-4-6|Anthropic",
    #model="claude-haiku-4.5",
    #model="gemini-2.5-flash-lite",
    messages=[{"role": "user", "content": "What is the meaning of life?"}],
)
print(response.choices[0].message.content)
# Out:
# Short answer: there’s no single, universally agreed “meaning of life.” Different traditions, sciences, and individuals answer that question in different ways. What matters most is what gives your life meaning — something you can discover, create, and change.
#
# Ways people find meaning
# - Biological: from a scientific standpoint, life’s basic “purpose” is survival and reproduction — passing on genes and sustaining life.
# - Philosophical:
#   - Nihilism: there is no inherent meaning.
#   - Existentialism: life has no given meaning, so you must create your own through choices and commitment.
#   - Absurdism: the universe is indifferent, and meaningfulness comes from embracing the absurd and continuing anyway.
# - Religious/spiritual: many religions offer meanings tied to serving God(s), spiritual growth, moral duty, or preparing for an afterlife.
# - Humanistic/practical: meaning arises from relationships, contributing to others, pursuing goals, creativity, and personal growth.
#
# How to find or build meaning in your life
# - Clarify values: What matters to you most (honesty, compassion, mastery, freedom, connection)?
# - Set meaningful goals: projects that align with your values and give you a sense of progress.
# - Invest in relationships: close connections consistently rank as the largest source of life satisfaction.
# - Contribute: helping others, mentoring, or volunteering often creates lasting purpose.
# - Engage in flow: activities that challenge you and absorb your attention (work, art, sport, study).
# - Reflect and adapt: meaning can change with life stages; revisit your priorities regularly.
# - Practice gratitude and presence: noticing what’s good can shift perspective toward significance.
#
# Quick exercises you can try
# - Ask yourself: What would I do if money and judgment weren’t issues? What would I regret not doing?
# - List three moments you felt deeply satisfied and see what they share.
# - Try a short volunteering stint or teach someone a skill — notice how it feels.
#
# Final thought
# Meaning is both discovered and made. You can look outward to philosophies and faiths for frameworks, but ultimately meaning is about what you choose to care about and act on. If you want, I can help you explore your values, generate meaningful goals, or suggest exercises tailored to your situation. Which would you prefer?
